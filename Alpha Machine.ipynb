# %% [markdown]
# ## Import Library

# %%
from machine_lib import *

# %% [markdown]
# ## 1, Login
# 在machine_lib文件的login方法中填写用户名和密码后保存然后来到本文件Restart Kernal后重新import machine_lib

# %%
s = login()
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}

# %% [markdown]
# ## 2, get data fields

# %%
df = get_datafields(s, dataset_id = 'analyst4', region='USA', universe='TOP3000', delay=1)
print(df)
# Out:
# Got count: 653
# Rate limit exceeded at offset 0. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 100. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 200. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 250. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 400. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 450. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 500. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 600. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 650. Waiting 2 seconds (attempt 1/3)...
#                                             id  \
# 0    actual_cashflow_per_share_value_quarterly
# 1              actual_dividend_value_quarterly
# 2                   actual_eps_value_quarterly
# 3                    actual_sales_value_annual
# 4                 actual_sales_value_quarterly
# ..                                         ...
# 648                        total_assets_amount
# 649                total_assets_reported_value
# 650                total_goodwill_actual_value
# 651                      total_goodwill_amount
# 652              total_goodwill_reported_value
#
#                                            description  \
# 0    Cash Flow Per Share - actual value for the qua...
# 1              Dividend - Actual value for the quarter
# 2    Earnings Per Share (Income Statement/Per Share...
# 3                                 Sales - Actual Value
# 4    Sales - Value in financial services income sta...
# ..                                                 ...
# 648                        Total Assets - actual value
# 649                        Total Assets - actual value
# 650         Total Goodwill - announced financial value
# 651                             Total Goodwill - Value
# 652          Total Goodwill - Actual Value in Millions
#
#                                                dataset  \
# 0    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 1    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 2    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 3    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 4    {'id': 'analyst4', 'name': 'Analyst Estimate D...
# ..                                                 ...
# 648  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 649  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 650  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 651  {'id': 'analyst4', 'name': 'Analyst Estimate D...
# 652  {'id': 'analyst4', 'name': 'Analyst Estimate D...
#
#                                  category  \
# 0    {'id': 'analyst', 'name': 'Analyst'}
# 1    {'id': 'analyst', 'name': 'Analyst'}
# 2    {'id': 'analyst', 'name': 'Analyst'}
# 3    {'id': 'analyst', 'name': 'Analyst'}
# 4    {'id': 'analyst', 'name': 'Analyst'}
# ..                                    ...
# 648  {'id': 'analyst', 'name': 'Analyst'}
# 649  {'id': 'analyst', 'name': 'Analyst'}
# 650  {'id': 'analyst', 'name': 'Analyst'}
# 651  {'id': 'analyst', 'name': 'Analyst'}
# 652  {'id': 'analyst', 'name': 'Analyst'}
#
#                                            subcategory region  delay universe  \
# 0    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 1    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 2    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 3    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 4    {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# ..                                                 ...    ...    ...      ...
# 648  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 649  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 650  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 651  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
# 652  {'id': 'analyst-analyst-estimates', 'name': 'A...    USA      1  TOP3000
#
#        type  dateCoverage  coverage  userCount  alphaCount themes
# 0    MATRIX           1.0    0.4684        128         170     []
# 1    MATRIX           1.0    0.6120         33          37     []
# 2    MATRIX           1.0    1.0000        154         263     []
# 3    MATRIX           1.0    0.9943        115         137     []
# 4    MATRIX           1.0    1.0000        106         134     []
# ..      ...           ...       ...        ...         ...    ...
# 648  MATRIX           1.0    0.8035         51          73     []
# 649  MATRIX           1.0    0.6486         61         118     []
# 650  MATRIX           1.0    0.3761         58          61     []
# 651  MATRIX           1.0    0.5285         17          20     []
# 652  MATRIX           1.0    0.3761         37          38     []
#
# [653 rows x 14 columns]

# %% [markdown]
# ### Matrix Data

# %%
print(df[df['type'] == "MATRIX"]["id"].tolist())
pc_fields = process_datafields(df, "matrix")
print(pc_fields)
# Out:
l4_netprofit_high', 'anl4_netprofit_low', 'anl4_netprofit_mean', 'anl4_netprofit_median', 'anl4_netprofit_number', 'anl4_netprofit_std', 'anl4_netprofit_value', 'anl4_netprofita_high', 'anl4_netprofita_low', 'anl4_netprofita_mean', 'anl4_netprofita_median', 'anl4_netprofita_number', 'anl4_netprofita_std', 'anl4_netprofita_value', 'anl4_ptp_flag', 'anl4_ptp_high', 'anl4_ptp_low', 'anl4_ptp_mean', 'anl4_ptp_median', 'anl4_ptp_number', 'anl4_ptp_value', 'anl4_ptpr_flag', 'anl4_ptpr_high', 'anl4_ptpr_low', 'anl4_ptpr_mean', 'anl4_ptpr_median', 'anl4_ptpr_number', 'anl4_qf_az_cfps_mean', 'anl4_qf_az_cfps_median', 'anl4_qf_az_cfps_number', 'anl4_qf_az_div_mean', 'anl4_qf_az_div_median', 'anl4_qf_az_div_number', 'anl4_qf_az_dts_spe', 'anl4_qf_az_eps', 'anl4_qf_az_eps_mean', 'anl4_qf_az_eps_number', 'anl4_qf_az_hgih_spe', 'anl4_qf_az_hgih_spfc', 'anl4_qf_az_hgih_vid', 'anl4_qf_az_wol_spe', 'anl4_qf_az_wol_spfc', 'anl4_qf_az_wol_vid', 'anl4_qfd1_az_cfps_median', 'anl4_qfd1_az_cfps_number', 'anl4_qfd1_az_div_median', 'anl4_qfd1_az_div_number', 'anl4_qfd1_az_dts_spe', 'anl4_qfd1_az_eps_number', 'anl4_qfd1_az_hgih_spe', 'anl4_qfd1_az_hgih_spfc', 'anl4_qfd1_az_hgih_vid', 'anl4_qfd1_az_wol_spe', 'anl4_qfd1_az_wol_spfc', 'anl4_qfd1_az_wol_vid', 'anl4_qfd1_azeps', 'anl4_qfv4_cfps_high', 'anl4_qfv4_cfps_low', 'anl4_qfv4_cfps_mean', 'anl4_qfv4_cfps_median', 'anl4_qfv4_cfps_number', 'anl4_qfv4_div_high', 'anl4_qfv4_div_low', 'anl4_qfv4_div_mean', 'anl4_qfv4_div_median', 'anl4_qfv4_div_number', 'anl4_qfv4_dts_spe', 'anl4_qfv4_eps_high', 'anl4_qfv4_eps_low', 'anl4_qfv4_eps_mean', 'anl4_qfv4_eps ...
# ['winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actual_dividend_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actual_eps_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actual_sales_value_annual, 120), std=4)', 'winsorize(ts_backfill(actual_sales_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actuals_value_currency_code, 120), std=4)', 'winsorize(ts_backfill(anl4_adjusted_netincome_ft, 120), std=4)', 'winsorize(ts_backfill(anl4_af_cfps_value, 120), std=4)', 'winsorize(ts_backfill(anl4_af_div_value, 120), std=4)', 'winsorize(ts_backfill(anl4_af_eps_value, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_high, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_low, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_median, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_number, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_high, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_low, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_median, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_number, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_std, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_dts_spe, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_high, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_low, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_number, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_median_eps, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_high, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_low, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_median, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_number, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_value, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_high, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_low, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_number, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_std, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_value, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_high, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_low, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_median, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_number, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_value, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_high, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_low, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_median, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_number, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_value, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_high, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_low, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_median, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_number, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_value, 120), std=4)', 'winsorize(ts_backfill(anl4_dts_ptp, 120), std=4)', 'winsorize(ts_backfill(anl4_dts_rspe, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_high, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_low, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_median, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_number, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_std, 120), std=4)', 'winsorize(ts_backfil ...

# %% [markdown]
# ### Vector Data

# %%
df = get_datafields(s, dataset_id='news12', region='USA', universe='TOP3000', delay=1)
print(df[df['type'] == "VECTOR"]["id"].tolist())
print(process_datafields(df, "vector"))
# Out:
# Got count: 322
# Rate limit exceeded at offset 50. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset
nws12_mainz_120_min', 'nws12_mainz_1_minute', 'nws12_mainz_1l', 'nws12_mainz_1p', 'nws12_mainz_1s', 'nws12_mainz_2l', 'nws12_mainz_2p', 'nws12_mainz_2s', 'nws12_mainz_30_min', 'nws12_mainz_30_seconds', 'nws12_mainz_3l', 'nws12_mainz_3p', 'nws12_mainz_3s', 'nws12_mainz_41rta', 'nws12_mainz_4l', 'nws12_mainz_4p', 'nws12_mainz_4s', 'nws12_mainz_57l', 'nws12_mainz_57p', 'nws12_mainz_57s', 'nws12_mainz_5_min', 'nws12_mainz_5l', 'nws12_mainz_5p', 'nws12_mainz_5s', 'nws12_mainz_60_min', 'nws12_mainz_90_min', 'nws12_mainz_allticks', 'nws12_mainz_allvwap', 'nws12_mainz_atrratio', 'nws12_mainz_close_vol', 'nws12_mainz_curr_vol', 'nws12_mainz_dayopen', 'nws12_mainz_div_y', 'nws12_mainz_eodclose', 'nws12_mainz_eodhigh', 'nws12_mainz_eodlow', 'nws12_mainz_eodvwap', 'nws12_mainz_epsactual', 'nws12_mainz_highexcstddev', 'nws12_mainz_lowexcstddev', 'nws12_mainz_mainvwap', 'nws12_mainz_maxdnamt', 'nws12_mainz_maxdown', 'nws12_mainz_maxup', 'nws12_mainz_maxupamt', 'nws12_mainz_mktcap', 'nws12_mainz_mov_vol', 'nws12_mainz_newrecord', 'nws12_mainz_newssess', 'nws12_mainz_open_vol', 'nws12_mainz_opengap', 'nws12_mainz_peratio', 'nws12_mainz_postvwap', 'nws12_mainz_prev_vol', 'nws12_mainz_prevclose', 'nws12_mainz_prevday', 'nws12_mainz_prevwap', 'nws12_mainz_provider', 'nws12_mainz_range', 'nws12_mainz_rangeamt', 'nws12_mainz_rangestddev', 'nws12_mainz_reportsess', 'nws12_mainz_result1', 'nws12_mainz_result2', 'nws12_mainz_result_vs_index', 'nws12_mainz_short_interest', 'nws12_mainz_sl', 'nws12_mainz_spyclose', 'nws12_mainz_spylast', 'nws12_mainz_tonhigh', 'nws12_mainz_tonlast', 'nws12_mainz_tonlow', 'nws12_mainz_vol_ratio', 'nws12_mainz_volstddev', 'nws12_prez_01l', 'nws12_prez_01p', 'nws12_prez_01s', 'nws12_prez_02l', 'nws12_prez_02 ...
# ['winsorize(ts_backfill(vec_avg(nws12_afterhsz_01l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_01l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_01p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_01p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_01s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_01s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_02l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_02l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_02p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_02p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_02s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_02s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_10_min), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_10_min), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_120_min), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_120_min), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_1_minute), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_1_minute), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_1l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_1l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_1p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_1p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_1s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_1s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_2l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_2l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_2p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_2p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_2s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_2s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_30_min), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_30_min), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_3l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_3l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_3p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_3p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_3s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_3s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_41rta), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_41rta), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_4l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_4l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_4p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_4p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_4s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_4s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_57l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_57l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_57p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_57p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_57s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_57s), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_5_min), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_5_min), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_5l), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_5l), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_5p), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_afterhsz_5p), 120), std=4)', 'winsorize(ts_backfill(vec_avg(nws12_afterhsz_5s), 120), std=4)', 'winsorize(ts_backfill(vec_sum(nws12_ ...

# %% [markdown]
# ## 3, Alpha factory
# ### start with First Order

# %%
first_order = first_order_factory(pc_fields, ts_ops)
print(first_order[:10])
print(len(first_order))
# Out:
# ['winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 5)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 22)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 66)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 240)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 5)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 22)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 66)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)']
# 26264

# %%
# Pad initial decay with alpha
init_decay = 6
fo_alpha_list = []
for alpha in first_order:
    fo_alpha_list.append((alpha, init_decay))
random.shuffle(fo_alpha_list)
print(len(fo_alpha_list))
print(fo_alpha_list[:5])
# Out:
# 26264
# [('ts_rank(winsorize(ts_backfill(anl4_qf_az_div_median, 120), std=4), 120)', 6), ('ts_zscore(winsorize(ts_backfill(sales_max_guidance_value, 120), std=4), 22)', 6), ('ts_mean(winsorize(ts_backfill(anl4_ptpr_median, 120), std=4), 120)', 6), ('ts_delay(winsorize(ts_backfill(dividend_max_guidance_quarterly, 120), std=4), 120)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_totgw_high, 120), std=4), 5)', 6)]

# %%
# Load alphas to task pools
fo_pools = load_task_pool(fo_alpha_list, 10, 9)
print(fo_pools[0])
# Out:
# [[('ts_rank(winsorize(ts_backfill(anl4_qf_az_div_median, 120), std=4), 120)', 6), ('ts_zscore(winsorize(ts_backfill(sales_max_guidance_value, 120), std=4), 22)', 6), ('ts_mean(winsorize(ts_backfill(anl4_ptpr_median, 120), std=4), 120)', 6), ('ts_delay(winsorize(ts_backfill(dividend_max_guidance_quarterly, 120), std=4), 120)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_totgw_high, 120), std=4), 5)', 6), ('ts_delta(winsorize(ts_backfill(total_assets_reported_value, 120), std=4), 5)', 6), ('ts_rank(winsorize(ts_backfill(dividend_estimate_average, 120), std=4), 22)', 6), ('ts_delay(winsorize(ts_backfill(sales_estimate_minimum, 120), std=4), 5)', 6), ('ts_std_dev(winsorize(ts_backfill(anl4_qf_az_div_mean, 120), std=4), 240)', 6), ('ts_std_dev(winsorize(ts_backfill(anl4_bvps_value, 120), std=4), 120)', 6)], [('ts_std_dev(winsorize(ts_backfill(anl4_netprofita_low, 120), std=4), 5)', 6), ('ts_zscore(winsorize(ts_backfill(min_net_profit_guidance, 120), std=4), 66)', 6), ('ts_mean(winsorize(ts_backfill(pretax_income_reported, 120), std=4), 5)', 6), ('ts_sum(winsorize(ts_backfill(cash_flow_from_operations, 120), std=4), 120)', 6), ('ts_quantile(winsorize(ts_backfill(min_capex_guidance, 120), std=4), 5)', 6), ('ts_zscore(winsorize(ts_backfill(research_development_expense, 120), std=4), 5)', 6), ('ts_arg_min(winsorize(ts_backfill(anl4_ptpr_mean, 120), std=4), 5)', 6), ('ts_mean(winsorize(ts_backfill(anl4_ptp_flag, 120), std=4), 66)', 6), ('ts_zscore(winsorize(ts_backfill(min_share_buyback_guidance, 120), std=4), 66)', 6), ('ts_rank(winsorize(ts_backfill(max_gross_income_guidance, 120), std=4), 22)', 6)], [('ts_std_dev(winsorize(ts_backfill(anl4_fcfps_mean, 120), std=4), 5)', 6), ('ts_rank(winsorize(ts_backfill(actual_eps_value_quarterly, 120), std=4), 240)', 6), ('ts_sum(winsorize(ts_backfill(eps_max_guidance_quarterly, 120), std=4), 120)', 6), ('ts_zscore(winsorize(ts_backfill(sales_min_guidance_value, 120), std=4), 120)', 6), ('ts_std_dev(winsorize(ts_backfill(max_total_goodwill_guidance_2, 120), std=4), 66)', 6), ('ts_sum(winsorize(ts_backfill(anl4_qf_az_wol_vid, 120), std=4), 66)', 6), ('ts_sum(winsorize(ts_backfill(capital_expenditure_max_guidance_qtr, 120), std=4), 5)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_gric_flag, 120), std=4), 22)', 6), ('ts_scale(winsorize(ts_backfill(anl4_dts_ptp, 120), std=4), 5)', 6), ('ts_rank(winsorize(ts_backfill(selling_general_admin_expense_reported_value, 120), std=4), 66)', 6)], [('ts_delay(winsorize(ts_backfill(funds_from_operations_max_guidance, 120), std=4), 66)', 6), ('ts_std_dev(winsorize(ts_backfill(est_netprofit_adj, 120), std=4), 240)', 6), ('ts_mean(winsorize(ts_backfill(max_ebit_guidance, 120), std=4), 5)', 6), ('ts_sum(winsorize(ts_backfill(gross_income_reported_value, 120), std=4), 120)', 6), ('ts_rank(winsorize(ts_backfill(max_net_profit_guidance, 120), std=4), 22)', 6), ('ts_arg_max(winsorize(ts_backfill(min_customized_eps_guidance, 120), std=4), 240)', 6), ('ts_arg_min(winsorize(ts_backfill(min_ebit_guidance, 120), std=4), 66)', 6), ('ts_arg_min(winsorize(ts_backfill(book_value_per_share_min_guidance_qtr, 120), std=4), 66)', 6), ('ts_arg_min(winsorize(ts_backfill(anl4_tbvps_median, 120), std=4), 120)', 6), ('ts_std_dev(winsorize(ts_backfill(anl4_netdebt_flag, 120), std=4), 22)', 6)], [('ts_zscore(winsorize(ts_backfill(anl4_bvps_mean, 120), std=4), 5)', 6), ('ts_std_dev(winsorize(ts_backfill(anl4_ebit_std, 120), std=4), 22)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_gric_median, 120), std=4), 66)', 6), ('ts_scale(winsorize(ts_backfill(anl4_qf_az_div_number, 120), std=4), 120)', 6), ('ts_mean(winsorize(ts_backfill(anl4_tbvps_median, 120), std=4), 240)', 6), ('ts_scale(winsorize(ts_backfill(free_cash_flow_reported_value, 120), std=4), 5)', 6), ('ts_arg_max(winsorize(ts_backfill(min_free_cash_flow_per_share_guidance, 120), std=4), 120)', 6), ('ts_std_dev(winsorize(ts_backfill(goodwill_min_guidance_qtr, 120), std=4), 66)', 6), ('ts_scale(winsorize(ts_backfill(min_tangible_book_valu ...

# %% [markdown]
# ## 4, simulate alphas

# %%
# Simulate First Order
multi_simulate(fo_pools, "SUBINDUSTRY", "USA", "TOP3000", 0)
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}
# Simulation mode: single (auto, permissions=[])
# Single simulation 0.0 hit concurrency limit, waiting 15.0 seconds before retry (1/20)
# Single simulation 0.0 finished with status=COMPLETE, alpha_id=YPW2ggdM
# Single simulation 0.1 finished with status=COMPLETE, alpha_id=A1Og7xXW
# Single simulation 0.2 finished with status=COMPLETE, alpha_id=RRk21Ozz
# Single simulation 0.3 finished with status=COMPLETE, alpha_id=1YnapQrJ
# Single simulation 0.4 finished with status=COMPLETE, alpha_id=om93NY9n
# Single simulation 0.5 finished with status=COMPLETE, alpha_id=9qAapW2V
# Single simulation 0.6 finished with status=COMPLETE, alpha_id=78Kazvr5
# Single simulation 0.7 finished with status=COMPLETE, alpha_id=XgY2o37l
# Single simulation 0.8 finished with status=COMPLETE, alpha_id=e7qdzA2d
# Single simulation 0.9 finished with status=COMPLETE, alpha_id=LLlg7ROL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Simulate First Order
# ----> 2 multi_simulate(fo_pools, "SUBINDUSTRY", "USA", "TOP3000", 0)
#
# File ~/worldquant/machine_lib.py:309, in multi_simulate(alpha_pools, neut, region, universe, start, mode)
#     306         if not simulation_progress_url:
#     307             continue
# --> 309         wait_for_single_simulation_completion(s, simulation_progress_url, y, idx)
#     310 except PermissionError as e:
#     311     print(f"Permission error: {e}")
#
# File ~/worldquant/machine_lib.py:126, in wait_for_single_simulation_completion(s, progress_url, task_idx, alpha_idx)
#     125 def wait_for_single_simulation_completion(s, progress_url, task_idx, alpha_idx):
# --> 126     simulation_progress = wait_for_simulation_progress(s, progress_url)
#     127     try:
#     128         progress_json = simulation_progress.json()
#
# File ~/worldquant/machine_lib.py:74, in wait_for_simulation_progress(s, progress_url)
#      72 retry_after = simulation_progress.headers.get("Retry-After")
#      73 if retry_after:
# ---> 74     sleep(float(retry_after))
#      75     continue
#      76 return simulation_progress
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5, Select alphas
# go to web alphas penal to look for the number and date to track for next order improve

# %%
## get promising alphas to improve in the next order
fo_tracker = get_alphas("01-22", "01-23", 1.2, 1, "USA", 100, "track")
print(len(fo_tracker))
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}
# 0
# count: 0
# 0

# %% [markdown]
# #### Prune 剪枝

# %%
fo_layer = prune(fo_tracker, 'mdl26', 5)

# %% [markdown]
# ## 6, Next order improvement - Second Order
# second order: ts_ops(field, days) -> group_ops(ts_ops(field, days), group)

# %%
so_alpha_list = []
group_ops = ["group_neutralize", "group_rank", "group_zscore"]

for expr, decay in fo_layer:
    for alpha in get_group_second_order_factory([expr], group_ops, "USA"):
        so_alpha_list.append((alpha,decay))

random.shuffle(so_alpha_list)
print(len(so_alpha_list))
print(so_alpha_list[:3])
# Out:
# 0
# []

# %% [markdown]
# ### Simulate second order

# %%
so_pools = load_task_pool(so_alpha_list, 10, 9)
multi_simulate(so_pools, 'SUBINDUSTRY', 'USA', 'TOP3000', 0)

# %% [markdown]
# ## Higher Order for improvement - Third Order
# group_ops(ts_ops(field, days), group) -> trade_when(entre_event, group_ops(ts_ops(field, days), group), exit_event)

# %%
## get promising alphas from second order to improve in the third order
so_tracker = get_alphas("01-22", "01-23", 1.4, 1, "USA", 110, "track")

print(len(so_tracker))

so_layer = prune(so_tracker, 'mdl26', 5)
th_alpha_list = []

for expr, decay in so_layer:
    for alpha in trade_when_factory("trade_when",expr,"USA"):
        th_alpha_list.append((alpha,decay))

random.shuffle(th_alpha_list)        
print(len(th_alpha_list))

# %% [markdown]
# ### Simulate Third Order

# %%
# Simulate third order
th_pools = load_task_pool(th_alpha_list, 10, 9)
multi_simulate(th_pools, 'SUBINDUSTRY', 'USA', 'TOP3000', 0)

# %% [markdown]
# ## 7, Get submittable alphas

# %%
# 1.58 sharpe, 1 fitness, "submit"参数
th_tracker = get_alphas("07-16", "07-20", 1.58, 1, "USA", 200, "submit")
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}
# 0
# 100
# count: 0

# %%
## 将get的alpha的id取出至stone_bag，用api check submission
stone_bag = []
for alpha in th_tracker:
    stone_bag.append(alpha[0])
print(len(stone_bag))
gold_bag = []
check_submission(stone_bag, gold_bag, 0)

# %%
# 打印可提交的alpha信息并按sharpe排序，在网页上找到alpha手动提交
view_alphas(gold_bag)

# %% [markdown]
# ## 8, fine-tune submittable alphas
# neutralization, performance comparison, turnover, margin
