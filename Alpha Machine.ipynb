# %% [markdown]
# ## Import Library

# %%
from machine_lib import *

# %% [markdown]
# ## 1, Login
# 在machine_lib文件的login方法中填写用户名和密码后保存然后来到本文件Restart Kernal后重新import machine_lib

# %%
s = login()
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}

# %% [markdown]
# ## 2, get data fields

# %%
df = get_datafields(s, dataset_id = 'fundamental6', region='USA', universe='TOP3000', delay=1)
print(df)
# Out:
# Got count: 886
# Rate limit exceeded at offset 50. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 150. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 200. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 300. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 350. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 500. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 650. Waiting 2 seconds (attempt 1/3)...
# Rate limit exceeded at offset 750. Waiting 2 seconds (attempt 1/3)...
#                   id                                   description  \
# 0             assets                                Assets - Total
# 1        assets_curr                        Current Assets - Total
# 2       bookvalue_ps                          Book Value Per Share
# 3              capex                          Capital Expenditures
# 4               cash                                          Cash
# ..               ...                                           ...
# 881            sales                          Sales/Turnover (Net)
# 882     sales_growth                   Growth in Sales (Quarterly)
# 883         sales_ps                   Sales per Share (Quarterly)
# 884      sga_expense  Selling, General and Administrative Expenses
# 885  working_capital               Working Capital (Balance Sheet)
#
#                                                dataset  \
# 0    {'id': 'fundamental6', 'name': 'Company Fundam...
# 1    {'id': 'fundamental6', 'name': 'Company Fundam...
# 2    {'id': 'fundamental6', 'name': 'Company Fundam...
# 3    {'id': 'fundamental6', 'name': 'Company Fundam...
# 4    {'id': 'fundamental6', 'name': 'Company Fundam...
# ..                                                 ...
# 881  {'id': 'fundamental6', 'name': 'Company Fundam...
# 882  {'id': 'fundamental6', 'name': 'Company Fundam...
# 883  {'id': 'fundamental6', 'name': 'Company Fundam...
# 884  {'id': 'fundamental6', 'name': 'Company Fundam...
# 885  {'id': 'fundamental6', 'name': 'Company Fundam...
#
#                                          category  \
# 0    {'id': 'fundamental', 'name': 'Fundamental'}
# 1    {'id': 'fundamental', 'name': 'Fundamental'}
# 2    {'id': 'fundamental', 'name': 'Fundamental'}
# 3    {'id': 'fundamental', 'name': 'Fundamental'}
# 4    {'id': 'fundamental', 'name': 'Fundamental'}
# ..                                            ...
# 881  {'id': 'fundamental', 'name': 'Fundamental'}
# 882  {'id': 'fundamental', 'name': 'Fundamental'}
# 883  {'id': 'fundamental', 'name': 'Fundamental'}
# 884  {'id': 'fundamental', 'name': 'Fundamental'}
# 885  {'id': 'fundamental', 'name': 'Fundamental'}
#
#                                            subcategory region  delay universe  \
# 0    {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 1    {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 2    {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 3    {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 4    {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# ..                                                 ...    ...    ...      ...
# 881  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 882  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 883  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 884  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
# 885  {'id': 'fundamental-fundamental-data', 'name':...    USA      1  TOP3000
#
#        type  dateCoverage  coverage  userCount  alphaCount themes
# 0    MATRIX           1.0       0.5      46310      144947     []
# 1    MATRIX           1.0       0.5       3500       14639     []
# 2    MATRIX           1.0       0.5       2592        9737     []
# 3    MATRIX           1.0       0.5      11764       27184     []
# 4    MATRIX           1.0       0.5       2573       11619     []
# ..      ...           ...       ...        ...         ...    ...
# 881  MATRIX           1.0       0.5      11167       35587     []
# 882  MATRIX           1.0       0.5       2992        7826     []
# 883  MATRIX           1.0       0.5       1698        6321     []
# 884  MATRIX           1.0       0.5       1524        8034     []
# 885  MATRIX           1.0       0.5       1265        5436     []
#
# [886 rows x 14 columns]

# %% [markdown]
# ### Matrix Data

# %%
print(df[df['type'] == "MATRIX"]["id"].tolist())
pc_fields = process_datafields(df, "matrix")
print(pc_fields)
# Out:
l4_netprofita_high', 'anl4_netprofita_low', 'anl4_netprofita_mean', 'anl4_netprofita_median', 'anl4_netprofita_number', 'anl4_netprofita_std', 'anl4_netprofita_value', 'anl4_ptp_flag', 'anl4_ptp_high', 'anl4_ptp_low', 'anl4_ptp_mean', 'anl4_ptp_median', 'anl4_ptp_number', 'anl4_ptp_value', 'anl4_ptpr_flag', 'anl4_ptpr_high', 'anl4_ptpr_low', 'anl4_ptpr_mean', 'anl4_ptpr_median', 'anl4_ptpr_number', 'anl4_qf_az_cfps_mean', 'anl4_qf_az_cfps_median', 'anl4_qf_az_cfps_number', 'anl4_qf_az_div_mean', 'anl4_qf_az_div_median', 'anl4_qf_az_div_number', 'anl4_qf_az_dts_spe', 'anl4_qf_az_eps', 'anl4_qf_az_eps_mean', 'anl4_qf_az_eps_number', 'anl4_qf_az_hgih_spe', 'anl4_qf_az_hgih_spfc', 'anl4_qf_az_hgih_vid', 'anl4_qf_az_wol_spe', 'anl4_qf_az_wol_spfc', 'anl4_qf_az_wol_vid', 'anl4_qfd1_az_cfps_median', 'anl4_qfd1_az_cfps_number', 'anl4_qfd1_az_div_median', 'anl4_qfd1_az_div_number', 'anl4_qfd1_az_dts_spe', 'anl4_qfd1_az_eps_number', 'anl4_qfd1_az_hgih_spe', 'anl4_qfd1_az_hgih_spfc', 'anl4_qfd1_az_hgih_vid', 'anl4_qfd1_az_wol_spe', 'anl4_qfd1_az_wol_spfc', 'anl4_qfd1_az_wol_vid', 'anl4_qfd1_azeps', 'anl4_qfv4_cfps_high', 'anl4_qfv4_cfps_low', 'anl4_qfv4_cfps_mean', 'anl4_qfv4_cfps_median', 'anl4_qfv4_cfps_number', 'anl4_qfv4_div_high', 'anl4_qfv4_div_low', 'anl4_qfv4_div_mean', 'anl4_qfv4_div_median', 'anl4_qfv4_div_number', 'anl4_qfv4_dts_spe', 'anl4_qfv4_eps_high', 'anl4_qfv4_eps_low', 'anl4_qfv4_eps_mean', 'anl4_qfv4_eps ...
# ['winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actual_dividend_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actual_eps_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actual_sales_value_annual, 120), std=4)', 'winsorize(ts_backfill(actual_sales_value_quarterly, 120), std=4)', 'winsorize(ts_backfill(actuals_value_currency_code, 120), std=4)', 'winsorize(ts_backfill(anl4_adjusted_netincome_ft, 120), std=4)', 'winsorize(ts_backfill(anl4_af_cfps_value, 120), std=4)', 'winsorize(ts_backfill(anl4_af_div_value, 120), std=4)', 'winsorize(ts_backfill(anl4_af_eps_value, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_high, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_low, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_median, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_cfps_number, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_high, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_low, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_median, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_number, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_div_std, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_dts_spe, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_high, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_low, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_eps_number, 120), std=4)', 'winsorize(ts_backfill(anl4_afv4_median_eps, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_high, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_low, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_median, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_number, 120), std=4)', 'winsorize(ts_backfill(anl4_bvps_value, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_high, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_low, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_number, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_std, 120), std=4)', 'winsorize(ts_backfill(anl4_capex_value, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_high, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_low, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_median, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_number, 120), std=4)', 'winsorize(ts_backfill(anl4_cff_value, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_high, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_low, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_median, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_number, 120), std=4)', 'winsorize(ts_backfill(anl4_cfi_value, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_flag, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_high, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_low, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_median, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_number, 120), std=4)', 'winsorize(ts_backfill(anl4_cfo_value, 120), std=4)', 'winsorize(ts_backfill(anl4_dts_ptp, 120), std=4)', 'winsorize(ts_backfill(anl4_dts_rspe, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_high, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_low, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_mean, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit_median, 120), std=4)', 'winsorize(ts_backfill(anl4_ebit
 'fnd6_newqeventv110_cimiiq', 'fnd6_newqeventv110_ciotherq', 'fnd6_newqeventv110_cipenq', 'fnd6_newqeventv110_ciq', 'fnd6_newqeventv110_cisecglq', 'fnd6_newqeventv110_citotalq', 'fnd6_newqeventv110_cogsq', 'fnd6_newqeventv110_csh12q', 'fnd6_newqeventv110_cshfdq', 'fnd6_newqeventv110_cshiq', 'fnd6_newqeventv110_cshopq', 'fnd6_newqeventv110_cshoq', 'fnd6_newqeventv110_cshprq', 'fnd6_newqeventv110_cstkeq', 'fnd6_newqeventv110_cstkq', 'fnd6_newqeventv110_dcomq', 'fnd6_newqeventv110_diladq', 'fnd6_newqeventv110_dilavq', 'fnd6_newqeventv110_dlcq', 'fnd6_newqeventv110_doq', 'fnd6_newqeventv110_dpactq', 'fnd6_newqeventv110_drcq', 'fnd6_newqeventv110_drltq', 'fnd6_newqeventv110_dteaq', 'fnd6_newqeventv110_dtepq', 'fnd6_newqeventv110_dvpq', 'fnd6_newqeventv110_epsfiq', 'fnd6_newqeventv110_epspiq', 'fnd6_newqeventv110_epspxq', 'fnd6_newqeventv110_esopctq', 'fnd6_newqeventv110_esopnrq', 'fnd6_newqeventv110_esoprq', 'fnd6_newqeventv110_esoptq', 'fnd6_newqeventv110_fcaq', 'fnd6_newqeventv110_gdwlamq', 'fnd6_newqeventv110_gdwlia12', 'fnd6_newqeventv110_gdwliaq', 'fnd6_newqeventv110_gdwlipq', 'fnd6_newqeventv110_gdwlq', 'fnd6_newqeventv110_glaq', 'fnd6_newqeventv110_glcea12', 'fnd6_newqeventv110_glceaq', 'fnd6_newqeventv110_glced12', 'fnd6_newqeventv110_glcedq', 'fnd6_newqeventv110_glceeps12', 'fnd6_newqeventv110_glceepsq', 'fnd6_newqeventv110_glcepq', 'fnd6_newqeventv110_glpq', 'fnd6_newqeventv110_hedgeglq', 'fnd6_newqeventv110_ibadj12', 'fnd6_newqeventv110_ibadjq', 'fnd6_newqeventv110_ibcomq', 'fnd6_newqeventv110_ibmiiq', 'fnd6_newqeventv110_ibq', 'fnd6_newqeventv110_icaptq', 'fnd6_newqeventv110_intanoq', 'fnd6_newqeventv110_intanq', 'fnd6_newqeventv110 ...
# ['winsorize(ts_backfill(vec_avg(fnd6_capxs), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_capxs), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_caxts), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_caxts), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cogss), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cogss), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_actq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_actq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_apq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_apq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_atq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_atq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_ceqq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_ceqq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_dlttq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_dlttq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_dpq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_dpq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_epsf12), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_epsf12), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_epsfxq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_epsfxq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_epsx12), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_epsx12), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_lctq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_lctq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_ltq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_ltq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_nopiq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_nopiq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_oeps12), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_oeps12), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_oiadpq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_oiadpq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_oibdpq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_oibdpq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_opepsq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_opepsq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_rectq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_rectq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_req), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_req), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_cptnewqeventv110_saleq), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_cptnewqeventv110_saleq), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_curcddv), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_curcddv), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_divd), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_divd), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_dps), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_dps), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_dvrated), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_dvrated), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_emps), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_emps), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_esubs), 120), std=4)', 'winsorize(ts_backfill(vec_sum(fnd6_esubs), 120), std=4)', 'winsorize(ts_backfill(vec_avg(fnd6_eventv110_aqdq), 120), st ...

# %% [markdown]
# ## 3, Alpha factory
# ### start with First Order

# %%
first_order = first_order_factory(pc_fields, ts_ops)
print(first_order[:10])
print(len(first_order))
# Out:
# ['winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 5)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 22)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 66)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)', 'ts_rank(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 240)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 5)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 22)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 66)', 'ts_zscore(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)']
# 26264

# %%
# Pad initial decay with alpha
init_decay = 6
fo_alpha_list = []
for alpha in first_order:
    fo_alpha_list.append((alpha, init_decay))
random.shuffle(fo_alpha_list)
print(len(fo_alpha_list))
print(fo_alpha_list[:5])
# Out:
# 26264
# [('ts_sum(winsorize(ts_backfill(anl4_qf_az_wol_spe, 120), std=4), 22)', 6), ('ts_arg_min(winsorize(ts_backfill(goodwill_min_guidance_qtr, 120), std=4), 240)', 6), ('ts_scale(winsorize(ts_backfill(book_value_per_share_2, 120), std=4), 66)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_qfv4_eps_mean, 120), std=4), 5)', 6), ('ts_zscore(winsorize(ts_backfill(pretax_income_reported_min_guidance_qtr, 120), std=4), 5)', 6)]

# %%
# Load alphas to task pools
fo_pools = load_task_pool(fo_alpha_list, 10, 9)
print(fo_pools[0])
# Out:
# [[('ts_sum(winsorize(ts_backfill(anl4_qf_az_wol_spe, 120), std=4), 22)', 6), ('ts_arg_min(winsorize(ts_backfill(goodwill_min_guidance_qtr, 120), std=4), 240)', 6), ('ts_scale(winsorize(ts_backfill(book_value_per_share_2, 120), std=4), 66)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_qfv4_eps_mean, 120), std=4), 5)', 6), ('ts_zscore(winsorize(ts_backfill(pretax_income_reported_min_guidance_qtr, 120), std=4), 5)', 6), ('ts_sum(winsorize(ts_backfill(capital_expenditure_reported_value, 120), std=4), 22)', 6), ('ts_rank(winsorize(ts_backfill(anl4_ptpr_low, 120), std=4), 120)', 6), ('ts_arg_max(winsorize(ts_backfill(min_tangible_book_value_per_share_guidance, 120), std=4), 22)', 6), ('ts_delay(winsorize(ts_backfill(max_reported_eps_guidance_2, 120), std=4), 22)', 6), ('ts_rank(winsorize(ts_backfill(anl4_capex_high, 120), std=4), 240)', 6)], [('ts_std_dev(winsorize(ts_backfill(anl4_totassets_mean, 120), std=4), 120)', 6), ('ts_rank(winsorize(ts_backfill(anl4_tbvps_mean, 120), std=4), 240)', 6), ('ts_rank(winsorize(ts_backfill(sales_estimate_average_annual, 120), std=4), 22)', 6), ('ts_rank(winsorize(ts_backfill(dividend_estimate_standard_deviation, 120), std=4), 66)', 6), ('ts_scale(winsorize(ts_backfill(anl4_netdebt_number, 120), std=4), 120)', 6), ('ts_scale(winsorize(ts_backfill(anl4_totassets_number, 120), std=4), 5)', 6), ('ts_rank(winsorize(ts_backfill(anl4_afv4_cfps_median, 120), std=4), 5)', 6), ('ts_delta(winsorize(ts_backfill(sales_estimate_dispersion, 120), std=4), 120)', 6), ('ts_delta(winsorize(ts_backfill(anl4_netprofit_flag, 120), std=4), 22)', 6), ('ts_mean(winsorize(ts_backfill(anl4_qfv4_div_number, 120), std=4), 240)', 6)], [('ts_arg_min(winsorize(ts_backfill(min_stock_option_expense_guidance, 120), std=4), 66)', 6), ('ts_delta(winsorize(ts_backfill(min_adjusted_net_income_guidance, 120), std=4), 66)', 6), ('ts_rank(winsorize(ts_backfill(min_pretax_profit_guidance, 120), std=4), 240)', 6), ('ts_mean(winsorize(ts_backfill(anl4_gric_value, 120), std=4), 240)', 6), ('ts_mean(winsorize(ts_backfill(min_share_count_guidance, 120), std=4), 22)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_ebitda_mean, 120), std=4), 5)', 6), ('ts_rank(winsorize(ts_backfill(anl4_netprofit_high, 120), std=4), 22)', 6), ('ts_arg_max(winsorize(ts_backfill(anl4_netprofita_median, 120), std=4), 22)', 6), ('ts_quantile(winsorize(ts_backfill(anl4_netdebt_mean, 120), std=4), 66)', 6), ('winsorize(ts_backfill(anl4_totassets_low, 120), std=4)', 6)], [('ts_arg_max(winsorize(ts_backfill(max_shareholders_equity_guidance, 120), std=4), 5)', 6), ('ts_std_dev(winsorize(ts_backfill(anl4_qfv4_cfps_high, 120), std=4), 22)', 6), ('ts_sum(winsorize(ts_backfill(anl4_qf_az_hgih_spfc, 120), std=4), 5)', 6), ('ts_delta(winsorize(ts_backfill(min_financing_cashflow_guidance_2, 120), std=4), 120)', 6), ('ts_sum(winsorize(ts_backfill(anl4_afv4_cfps_number, 120), std=4), 66)', 6), ('winsorize(ts_backfill(anl4_qfv4_cfps_high, 120), std=4)', 6), ('ts_arg_max(winsorize(ts_backfill(max_net_debt_guidance, 120), std=4), 66)', 6), ('ts_mean(winsorize(ts_backfill(anl4_cfo_low, 120), std=4), 22)', 6), ('ts_mean(winsorize(ts_backfill(anl4_ebit_number, 120), std=4), 66)', 6), ('ts_mean(winsorize(ts_backfill(anl4_ptp_value, 120), std=4), 120)', 6)], [('ts_delay(winsorize(ts_backfill(sales_max_guidance_quarterly, 120), std=4), 5)', 6), ('ts_delay(winsorize(ts_backfill(cashflow_per_share_min_guidance, 120), std=4), 66)', 6), ('ts_rank(winsorize(ts_backfill(est_sales, 120), std=4), 5)', 6), ('ts_sum(winsorize(ts_backfill(actual_dividend_value_quarterly, 120), std=4), 5)', 6), ('ts_delta(winsorize(ts_backfill(anl4_netprofit_high, 120), std=4), 22)', 6), ('ts_quantile(winsorize(ts_backfill(max_net_profit_guidance, 120), std=4), 66)', 6), ('ts_std_dev(winsorize(ts_backfill(min_funds_from_operations_guidance, 120), std=4), 5)', 6), ('ts_arg_min(winsorize(ts_backfill(actual_cashflow_per_share_value_quarterly, 120), std=4), 120)', 6), ('ts_arg_max(winsorize(ts_backfill(net_profit_reported_v ...

# %% [markdown]
# ## 4, simulate alphas

# %%
# Simulate First Order
multi_simulate(fo_pools, "SUBINDUSTRY", "USA", "TOP3000", 0)
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}
# Simulation mode: single (auto, permissions=[])
# Single simulation 0.0 finished with status=COMPLETE, alpha_id=YP27vKVw
# Result 0.0.0: id=YP27vKVw       sharpe= 0.320 fitness= 0.170 turnover= 0.012 margin=  0.0057 decay=6
#   expr: ts_sum(winsorize(ts_backfill(anl4_qf_az_wol_spe, 120), std=4), 22)
# Error during simulation submission: HTTPSConnectionPool(host='api.worldquantbrain.com', port=443): Max retries exceeded with url: /simulations/2QC5hR9en5afcz5173EfV5vh (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1385 try:
# -> 1386     response.begin()
#    1387 except ConnectionError:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/http/client.py:294, in HTTPResponse._read_status(self)
#     291 if not line:
#     292     # Presumably, the server closed the connection before
#     293     # sending a valid response.
# --> 294     raise RemoteDisconnected("Remote end closed connection without"
#     295                              " response")
#     296 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# ProxyError: ('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response'))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/requests/adapters.py:645, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     644 try:
# --> 645     resp = conn.urlopen(
#     646         method=request.method,
#     647         url=url,
#     648         body=request.body,
#     649         headers=request.headers,
#     650         redirect=False,
#     651         assert_same_host=False,
#     652         preload_content=False,
#     653         decode_content=False,
#     654         retries=self.max_retries,
#     655         timeout=timeout,
#     656         chunked=chunked,
#     657     )
#     659 except (ProtocolError, OSError) as err:
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/urllib3/util/retry.py:535, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     534     reason = error or ResponseError(cause)
# --> 535     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     537 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.worldquantbrain.com', port=443): Max retries exceeded with url: /simulations/2QC5hR9en5afcz5173EfV5vh (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# File ~/worldquant/wq-assistant/machine_lib.py:449, in multi_simulate(alpha_pools, neut, region, universe, start, mode, results_csv)
#     447     continue
# --> 449 progress_json = wait_for_single_simulation_completion(s, simulation_progress_url, y, idx)
#     450 alpha_id = progress_json.get("alpha") if progress_json else None
#
# File ~/worldquant/wq-assistant/machine_lib.py:219, in wait_for_single_simulation_completion(s, progress_url, task_idx, alpha_idx)
#     218 def wait_for_single_simulation_completion(s, progress_url, task_idx, alpha_idx):
# --> 219     simulation_progress = wait_for_simulation_progress(s, progress_url)
#     220     try:
#
# File ~/worldquant/wq-assistant/machine_lib.py:164, in wait_for_simulation_progress(s, progress_url)
#     163 while True:
# --> 164     simulation_progress = s.get(progress_url)
#     165     retry_after = simulation_progress.headers.get("Retry-After")
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/requests/sessions.py:605, in Session.get(self, url, **kwargs)
#     604 kwargs.setdefault("allow_redirects", True)
# --> 605 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/requests/sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/requests/sessions.py:706, in Session.send(self, request, **kwargs)
#     705 # Send the request
# --> 706 r = adapter.send(request, **kwargs)
#     708 # Total elapsed time of the request (approximately)
#
# File ~/.pyenv/versions/worldquant/lib/python3.11/site-packages/requests/adapters.py:672, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     671 if isinstance(e.reason, _ProxyError):
# --> 672     raise ProxyError(e, request=request)
#     674 if isinstance(e.reason, _SSLError):
#     675     # This branch is for urllib3 v1.22 and later.
#
# ProxyError: HTTPSConnectionPool(host='api.worldquantbrain.com', port=443): Max retries exceeded with url: /simulations/2QC5hR9en5afcz5173EfV5vh (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Simulate First Order
# ----> 2 multi_simulate(fo_pools, "SUBINDUSTRY", "USA", "TOP3000", 0)
#
# File ~/worldquant/wq-assistant/machine_lib.py:461, in multi_simulate(alpha_pools, neut, region, universe, start, mode, results_csv)
#     459     except Exception as e:
#     460         print(f"Error during simulation submission: {e}")
# --> 461         sleep(600)
#     462         s = login()
#     464 print("pool %d task %d post done"%(x,y))
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5, Select alphas
# go to web alphas penal to look for the number and date to track for next order improve

# %%
## get promising alphas to improve in the next order
fo_tracker = get_alphas("01-22", "01-23", 1.2, 1, "USA", 100, "track")
print(len(fo_tracker))
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}
# 0
# count: 0
# 0

# %% [markdown]
# #### Prune 剪枝

# %%
fo_layer = prune(fo_tracker, 'mdl26', 5)

# %% [markdown]
# ## 6, Next order improvement - Second Order
# second order: ts_ops(field, days) -> group_ops(ts_ops(field, days), group)

# %%
so_alpha_list = []
group_ops = ["group_neutralize", "group_rank", "group_zscore"]

for expr, decay in fo_layer:
    for alpha in get_group_second_order_factory([expr], group_ops, "USA"):
        so_alpha_list.append((alpha,decay))

random.shuffle(so_alpha_list)
print(len(so_alpha_list))
print(so_alpha_list[:3])
# Out:
# 0
# []

# %% [markdown]
# ### Simulate second order

# %%
so_pools = load_task_pool(so_alpha_list, 10, 9)
multi_simulate(so_pools, 'SUBINDUSTRY', 'USA', 'TOP3000', 0)

# %% [markdown]
# ## Higher Order for improvement - Third Order
# group_ops(ts_ops(field, days), group) -> trade_when(entre_event, group_ops(ts_ops(field, days), group), exit_event)

# %%
## get promising alphas from second order to improve in the third order
so_tracker = get_alphas("01-22", "01-23", 1.4, 1, "USA", 110, "track")

print(len(so_tracker))

so_layer = prune(so_tracker, 'mdl26', 5)
th_alpha_list = []

for expr, decay in so_layer:
    for alpha in trade_when_factory("trade_when",expr,"USA"):
        th_alpha_list.append((alpha,decay))

random.shuffle(th_alpha_list)        
print(len(th_alpha_list))

# %% [markdown]
# ### Simulate Third Order

# %%
# Simulate third order
th_pools = load_task_pool(th_alpha_list, 10, 9)
multi_simulate(th_pools, 'SUBINDUSTRY', 'USA', 'TOP3000', 0)

# %% [markdown]
# ## 7, Get submittable alphas

# %%
# 1.58 sharpe, 1 fitness, "submit"参数
th_tracker = get_alphas("07-16", "07-20", 1.58, 1, "USA", 200, "submit")
# Out:
# Authentication: {"status_code": 201, "user_id": "SL75706", "permissions": []}
# 0
# 100
# count: 0

# %%
## 将get的alpha的id取出至stone_bag，用api check submission
stone_bag = []
for alpha in th_tracker:
    stone_bag.append(alpha[0])
print(len(stone_bag))
gold_bag = []
check_submission(stone_bag, gold_bag, 0)

# %%
# 打印可提交的alpha信息并按sharpe排序，在网页上找到alpha手动提交
view_alphas(gold_bag)

# %% [markdown]
# ## 8, fine-tune submittable alphas
# neutralization, performance comparison, turnover, margin
